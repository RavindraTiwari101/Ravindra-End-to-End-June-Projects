-- %%
-- ************** Create Catalog  ***************
-- CREATE CATALOG IF NOT EXISTS Juneproject_dev;
-- CREATE CATALOG IF NOT EXISTS Juneproject_qa;
-- CREATE CATALOG IF NOT EXISTS Juneproject_prod;

-- ************** Create Schema ***************

-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.bronze_dev;
-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.silver_dev;
-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.gold_dev;

-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.bronze_qa;
-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.silver_qa;
-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.gold_qa;


-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.bronze_prod;
-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.silver_prod;
-- CREATE SCHEMA IF NOT EXISTS Juneproject_dev.gold_prod;


--  Valomes (Source - file landing zone + archive)===

-- create volume if not exists saleslake_dev.bronze_dev.vol_saleslake_src_files_dev;
-- create volume if not exists saleslake_qa.bronze_qa.vol_saleslake_src_files_qa;
-- create volume if not exists saleslake_prd.bronze_prd.vol_saleslake_src_files_prod;

drop volume saleslake_prd.bronze_prd.vol_saleslake_src_files_prd;
