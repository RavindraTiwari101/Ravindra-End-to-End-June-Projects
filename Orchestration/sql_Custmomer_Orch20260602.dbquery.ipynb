-- %%
-- ************************ Customer Object *********
-- Bronze Layer :-
-- ===== EXISTING: rawCustomer  (managed table) Bronze Layer ===== SCD 2- 

CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawCustomer 
(
    customer_id STRING, customer_name STRING, email STRING,
    phone STRING, address STRING, city STRING, state STRING,
    country STRING, zip_code STRING, segment STRING,
    ingest_ts TIMESTAMP
);

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawCustomer
(
    customer_id STRING, customer_name STRING, email STRING,
    phone STRING, address STRING, city STRING, state STRING,
    country STRING, zip_code STRING, segment STRING,
    ingest_ts TIMESTAMP
);

CREATE TABLE IF NOT EXISTS saleslake_prod.bronze_prod.rawCustomer 
(
    customer_id STRING, customer_name STRING, email STRING,
    phone STRING, address STRING, city STRING, state STRING,
    country STRING, zip_code STRING, segment STRING,
    ingest_ts TIMESTAMP
);

-- -- ===== EXISTING: cleanedCustomer ===== Silver Layer -  SCD - 2
CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedCustomer
(
    customer_id INT, customer_name STRING, email STRING, phone STRING,
    address STRING, city STRING, state STRING, country STRING,
    zip_code STRING, segment STRING,
    ingest_ts TIMESTAMP
);

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedCustomer
(
    customer_id INT, customer_name STRING, email STRING, phone STRING,
    address STRING, city STRING, state STRING, country STRING,
    zip_code STRING, segment STRING,
    ingest_ts TIMESTAMP
);

CREATE TABLE IF NOT EXISTS saleslake_prod.silver_prod.cleanedCustomer 
(
    customer_id INT, customer_name STRING, email STRING, phone STRING,
    address STRING, city STRING, state STRING, country STRING,
    zip_code STRING, segment STRING,
    ingest_ts TIMESTAMP
);

-- ===== EXISTING: refinedCustomer  (SCD2, existing) ===== Gold Layer -

CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.refinedCustomer 
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id INT, customer_name STRING, email STRING, phone STRING,
    address STRING, city STRING, state STRING, country STRING,
    zip_code STRING, segment STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
);

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.refinedCustomer 
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id INT, customer_name STRING, email STRING, phone STRING,
    address STRING, city STRING, state STRING, country STRING,
    zip_code STRING, segment STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
);

CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.refinedCustomer 
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id INT, customer_name STRING, email STRING, phone STRING,
    address STRING, city STRING, state STRING, country STRING,
    zip_code STRING, segment STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
);


-- --  Production Bronze Layer
/*

truncate table saleslake_dev.bronze_dev.rawCustomer;
drop table saleslake_dev.bronze_dev.rawCustomer;

truncate table saleslake_qa.bronze_qa.rawCustomer;
drop table saleslake_qa.bronze_qa.rawCustomer;

truncate table saleslake_prod.bronze_prod.rawcustomer;
drop table saleslake_prod.bronze_prod.rawcustomer;

-- --  Production Silver Layer

truncate table saleslake_dev.silver_dev.cleanedcustomer;
drop table saleslake_dev.silver_dev.cleanedcustomer;

truncate table saleslake_prod.silver_prod.cleanedcustomer;
drop table saleslake_prod.silver_prod.cleanedcustomer;

truncate table saleslake_qa.silver_qa.cleanedcustomer;
drop table saleslake_qa.silver_qa.cleanedcustomer;

-- --  Production Gold Layer

truncate table saleslake_prod.gold_prod.refinedcustomer;
drop table saleslake_prod.gold_prod.refinedcustomer;

truncate table saleslake_qa.gold_qa.refinedcustomer;
drop table saleslake_qa.gold_qa.refinedcustomer;

truncate table saleslake_dev.gold_dev.refinedcustomer;
drop table saleslake_dev.gold_dev.refinedcustomer;
*/
