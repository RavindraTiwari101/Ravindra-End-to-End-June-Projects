-- %%
-- ===== EXISTING: rawInvoice  (external; already on AWS S3) ===== Bronze Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawInvoice 
(
    invoice_id STRING, invoice_number STRING, customer_id STRING,
    invoice_date STRING, due_date STRING,
    subtotal_amount STRING, discount_code STRING, discount_amount STRING,
    tax_amount STRING, total_amount STRING,
    payment_status STRING, payment_method STRING, payment_date STRING,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/source_files/invoice/';

-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/source_files/invoice/

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawInvoice
(
    invoice_id STRING, invoice_number STRING, customer_id STRING,
    invoice_date STRING, due_date STRING,
    subtotal_amount STRING, discount_code STRING, discount_amount STRING,
    tax_amount STRING, total_amount STRING,
    payment_status STRING, payment_method STRING, payment_date STRING,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/source_files/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prod.bronze_prod.rawInvoice 
(
    invoice_id STRING, invoice_number STRING, customer_id STRING,
    invoice_date STRING, due_date STRING,
    subtotal_amount STRING, discount_code STRING, discount_amount STRING,
    tax_amount STRING, total_amount STRING,
    payment_status STRING, payment_method STRING, payment_date STRING,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/source_files/invoice/';


-- ===== EXISTING: cleanedInvoice  (external on AWS S3) ===== Silver Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedInvoice 
(
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/silver/invoice/';

-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/silver/invoice/

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedInvoice 
(
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/silver/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prod.silver_prod.cleanedInvoice 
(
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP NOT NULL
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/silver/invoice/';


-- ===== EXISTING: refinedInvoice  (external on AWS S3) =====  Gold Layer
CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.refinedInvoice 
(
    invoice_sk BIGINT GENERATED ALWAYS AS IDENTITY,  -- surrogate key
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP,              -- raw ingestion timestamp
    is_active STRING,                 -- 'Y' or 'N'
    rec_version INT,                  -- version number for SCD2
    start_effective_ts TIMESTAMP,     -- when record became active
    end_effective_ts TIMESTAMP        -- when record was closed (9999-12-31 for active)
   
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/gold/invoice/';

--s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/gold/invoice/

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.refinedInvoice 
(
        invoice_sk BIGINT GENERATED ALWAYS AS IDENTITY,  -- surrogate key
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP,              -- raw ingestion timestamp
    is_active STRING,                 -- 'Y' or 'N'
    rec_version INT,                  -- version number for SCD2
    start_effective_ts TIMESTAMP,     -- when record became active
    end_effective_ts TIMESTAMP        -- when record was closed (9999-12-31 for active)
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/gold/invoice/';

CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.refinedInvoice 
(
    invoice_sk BIGINT GENERATED ALWAYS AS IDENTITY,  -- surrogate key
    invoice_id STRING NOT NULL, invoice_number STRING,
    customer_id BIGINT, invoice_date DATE, due_date DATE,
    subtotal_amount DECIMAL(18,2), discount_code STRING,
    discount_amount DECIMAL(18,2), tax_amount DECIMAL(18,2),
    total_amount DECIMAL(18,2),
    payment_status STRING, payment_method STRING, payment_date DATE,
    currency STRING, region STRING, store_id STRING, channel STRING,
    created_by STRING,
    ingest_ts TIMESTAMP,              -- raw ingestion timestamp
    is_active STRING,                 -- 'Y' or 'N'
    rec_version INT,                  -- version number for SCD2
    start_effective_ts TIMESTAMP,     -- when record became active
    end_effective_ts TIMESTAMP        -- when record was closed (9999-12-31 for active)
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/gold/invoice/';
