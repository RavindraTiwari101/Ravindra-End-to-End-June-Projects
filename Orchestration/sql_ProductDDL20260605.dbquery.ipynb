-- %%
%sql
-- ===== NEW: rawProduct  (external on AWS S3) ===== Bronze Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawProduct 
(
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost STRING, list_price STRING,
    launch_date STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/source_files/product';


CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawProduct 
(
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost STRING, list_price STRING,
    launch_date STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/source_files/product/';

CREATE TABLE IF NOT EXISTS saleslake_prod.bronze_prod.rawProduct 
(
    product_id STRING, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost STRING, list_price STRING,
    launch_date STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/source_files/product/';



-- ===== NEW: cleanedProduct  (external on AWS S3) ===== Silver Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedProduct 
(
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/silver/product/';


CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedProduct 
(
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/silver/product/';

CREATE TABLE IF NOT EXISTS saleslake_prod.silver_prod.cleanedProduct 
(
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/silver/product/';



-- ===== NEW: dim_product  (SCD Type 2, external on AWS S3) ===== Gold Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.dim_product 
(
    product_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/gold/dim_product/';


CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.dim_product 
(
    product_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/gold/dim_product/';

CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.dim_product 
(
    product_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    product_id INT, sku STRING, product_name STRING,
    category STRING, sub_category STRING, brand STRING,
    supplier STRING, unit_cost DECIMAL(18,2), list_price DECIMAL(18,2),
    launch_date DATE, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/gold/dim_product/';
