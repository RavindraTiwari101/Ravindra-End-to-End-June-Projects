-- %%
-- ===== NEW: rawRegion  (external on AWS S3) =====    Bronze Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawRegion
(
    region_id STRING, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    created_date STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/source_files/region/';


CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawRegion 
(
    region_id STRING, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    created_date STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/source_files/region/';


CREATE TABLE IF NOT EXISTS saleslake_prod.bronze_prod.rawRegion 
(
    region_id STRING, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    created_date STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/source_files/region/';


-- ===== NEW: cleanedRegion  (external on AWS S3) =====  Silver Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedRegion 
(
    region_id INT, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/silver/region/';


CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedRegion 
(
    region_id INT, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/silver/region/';

CREATE TABLE IF NOT EXISTS saleslake_prod.silver_prod.cleanedRegion 
(
    region_id INT, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    created_date DATE,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/silver/region/';


-- ===== NEW: dim_region  (SCD Type 1, external on AWS S3) ===== Gold Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.dim_region 
(
    region_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    region_id INT, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    initial_load_ts TIMESTAMP, last_updt_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/gold/dim_region/';

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.dim_region 
(
    region_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    region_id INT, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    initial_load_ts TIMESTAMP, last_updt_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/gold/dim_region/';

CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.dim_region 
(
    region_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    region_id INT, region_code STRING, region_name STRING,
    country STRING, sub_region STRING, regional_manager STRING,
    initial_load_ts TIMESTAMP, last_updt_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/gold/dim_region/';
