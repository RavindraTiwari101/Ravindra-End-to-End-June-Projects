-- %%
-- ===== ENHANCED: rawSales  (managed table; expanded schema with new FKs) ===== Bronze Layer
-- Bronze Layer Table ---


CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawSales 
(
    sale_id STRING, product_id STRING, store_id STRING,
    customer_id STRING, region_id STRING,
    quantity STRING, unit_price STRING, gross_amount STRING,
    discount_code STRING, discount_amount STRING,
    net_amount STRING, cost_amount STRING,
    sale_date STRING, payment_method STRING, channel STRING,
    ingest_ts TIMESTAMP
);

CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawSales 
(
    sale_id STRING, product_id STRING, store_id STRING,
    customer_id STRING, region_id STRING,
    quantity STRING, unit_price STRING, gross_amount STRING,
    discount_code STRING, discount_amount STRING,
    net_amount STRING, cost_amount STRING,
    sale_date STRING, payment_method STRING, channel STRING,
    ingest_ts TIMESTAMP
);

CREATE OR REPLACE TABLE saleslake_prod.bronze_prod.rawSales 
(
    sale_id STRING, product_id STRING, store_id STRING,
    customer_id STRING, region_id STRING,
    quantity STRING, unit_price STRING, gross_amount STRING,
    discount_code STRING, discount_amount STRING,
    net_amount STRING, cost_amount STRING,
    sale_date STRING, payment_method STRING, channel STRING,
    ingest_ts TIMESTAMP
);


-- ===== ENHANCED: cleanedSales ===== Silver Layer--

CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanedSales 
(
    sale_id BIGINT, product_id INT, store_id INT,
    customer_id INT, region_id INT,
    quantity INT, unit_price DECIMAL(18,2), gross_amount DECIMAL(18,2),
    discount_code STRING, discount_amount DECIMAL(18,2),
    net_amount DECIMAL(18,2), cost_amount DECIMAL(18,2),
    sale_date DATE, payment_method STRING, channel STRING,
    ingest_ts TIMESTAMP
)
PARTITIONED BY (sale_date);

CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanedSales 
(
    sale_id BIGINT, product_id INT, store_id INT,
    customer_id INT, region_id INT,
    quantity INT, unit_price DECIMAL(18,2), gross_amount DECIMAL(18,2),
    discount_code STRING, discount_amount DECIMAL(18,2),
    net_amount DECIMAL(18,2), cost_amount DECIMAL(18,2),
    sale_date DATE, payment_method STRING, channel STRING,
    ingest_ts TIMESTAMP
)
PARTITIONED BY (sale_date);

CREATE OR REPLACE TABLE saleslake_prod.silver_prod.cleanedSales 
(
    sale_id BIGINT, product_id INT, store_id INT,
    customer_id INT, region_id INT,
    quantity INT, unit_price DECIMAL(18,2), gross_amount DECIMAL(18,2),
    discount_code STRING, discount_amount DECIMAL(18,2),
    net_amount DECIMAL(18,2), cost_amount DECIMAL(18,2),
    sale_date DATE, payment_method STRING, channel STRING,
    ingest_ts TIMESTAMP
)
PARTITIONED BY (sale_date);

-- ===== EXISTING: refinedSales  (SCD2, existing schema) ===== Gold Layer
CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.refinedSales 
(
    sale_sk BIGINT GENERATED ALWAYS AS IDENTITY,  -- surrogate key
    sale_id BIGINT,
    product_id INT,
    store_id INT,
    customer_id INT,
    region_id INT,
    quantity INT,
    unit_price DECIMAL(18,2),
    gross_amount DECIMAL(18,2),
    discount_code STRING,
    discount_amount DECIMAL(18,2),
    net_amount DECIMAL(18,2),
    cost_amount DECIMAL(18,2),
    sale_date DATE,
    payment_method STRING,
    channel STRING,
    ingest_ts TIMESTAMP,              -- raw ingestion timestamp
    is_active STRING,                 -- 'Y' or 'N'
    rec_version INT,                  -- version number for SCD2
    start_effective_ts TIMESTAMP,     -- when record became active
    end_effective_ts TIMESTAMP        -- when record was closed (9999-12-31 for active)
)

PARTITIONED BY (sale_date);

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.refinedSales 
(
   sale_sk BIGINT GENERATED ALWAYS AS IDENTITY,  -- surrogate key
    sale_id BIGINT,
    product_id INT,
    store_id INT,
    customer_id INT,
    region_id INT,
    quantity INT,
    unit_price DECIMAL(18,2),
    gross_amount DECIMAL(18,2),
    discount_code STRING,
    discount_amount DECIMAL(18,2),
    net_amount DECIMAL(18,2),
    cost_amount DECIMAL(18,2),
    sale_date DATE,
    payment_method STRING,
    channel STRING,
    ingest_ts TIMESTAMP,              -- raw ingestion timestamp
    is_active STRING,                 -- 'Y' or 'N'
    rec_version INT,                  -- version number for SCD2
    start_effective_ts TIMESTAMP,     -- when record became active
    end_effective_ts TIMESTAMP        -- when record was closed (9999-12-31 for active)

)
PARTITIONED BY (sale_date);

CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.refinedSales 
(
  sale_sk BIGINT GENERATED ALWAYS AS IDENTITY,  -- surrogate key
    sale_id BIGINT,
    product_id INT,
    store_id INT,
    customer_id INT,
    region_id INT,
    quantity INT,
    unit_price DECIMAL(18,2),
    gross_amount DECIMAL(18,2),
    discount_code STRING,
    discount_amount DECIMAL(18,2),
    net_amount DECIMAL(18,2),
    cost_amount DECIMAL(18,2),
    sale_date DATE,
    payment_method STRING,
    channel STRING,
    ingest_ts TIMESTAMP,              -- raw ingestion timestamp
    is_active STRING,                 -- 'Y' or 'N'
    rec_version INT,                  -- version number for SCD2
    start_effective_ts TIMESTAMP,     -- when record became active
    end_effective_ts TIMESTAMP        -- when record was closed (9999-12-31 for active)
)
PARTITIONED BY (sale_date);
