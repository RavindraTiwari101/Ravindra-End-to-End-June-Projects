-- %%
%sql
-- ===== NEW: rawStore  (external on AWS S3) ============== Bronze Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.bronze_dev.rawStore 
(
    store_id STRING, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id STRING, manager_name STRING, opening_date STRING,
    square_feet STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/delta_tables/bronze_delta_tables/store/';

-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/delta_tables/bronze_delta_tables/store/

CREATE TABLE IF NOT EXISTS saleslake_qa.bronze_qa.rawStore 
(
    store_id STRING, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id STRING, manager_name STRING, opening_date STRING,
    square_feet STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/delta_tables/bronze_delta_tables/store/';


CREATE TABLE IF NOT EXISTS saleslake_prod.bronze_prod.rawStore 
(
    store_id STRING, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id STRING, manager_name STRING, opening_date STRING,
    square_feet STRING, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/delta_tables/bronze_delta_tables/store/';

-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/delta_tables/bronze_delta_tables/store/

-- ===== NEW: cleanedStore  (external on AWS S3) ===== SCD -2 ========= Silver Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.silver_dev.cleanedStore (
    store_id INT, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id INT, manager_name STRING, opening_date DATE,
    square_feet INT, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/delta_tables/silver_delta_tables/store/';

-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/delta_tables/silver_delta_tables/store/

CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedStore (
    store_id INT, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id INT, manager_name STRING, opening_date DATE,
    square_feet INT, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/delta_tables/silver_delta_tables/store/';
-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/delta_tables/silver_delta_tables/store/

CREATE TABLE IF NOT EXISTS saleslake_prod.silver_prod.cleanedStore 
(
    store_id INT, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id INT, manager_name STRING, opening_date DATE,
    square_feet INT, status STRING,
    ingest_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/delta_tables/silver_delta_tables/store/';
-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/delta_tables/silver_delta_tables/store/


-- ===== NEW: dim_store  (SCD Type 2, external on AWS S3) ===== Gold Layer

CREATE TABLE IF NOT EXISTS saleslake_dev.gold_dev.dim_store 
(
    store_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    store_id INT, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id INT, manager_name STRING, opening_date DATE,
    square_feet INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/delta_tables/gold_delta_tables/store/';
-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/dev/delta_tables/gold_delta_tables/store/

CREATE TABLE IF NOT EXISTS saleslake_qa.gold_qa.dim_store 
(
    store_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    store_id INT, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id INT, manager_name STRING, opening_date DATE,
    square_feet INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/delta_tables/gold_delta_tables/store/';
-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/qa/delta_tables/gold_delta_tables/store/


CREATE TABLE IF NOT EXISTS saleslake_prod.gold_prod.dim_store 
(
    store_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    store_id INT, store_code STRING, store_name STRING,
    store_type STRING, address STRING, city STRING, state STRING,
    region_id INT, manager_name STRING, opening_date DATE,
    square_feet INT, status STRING,
    is_active STRING, rec_version INT,
    start_effective_ts TIMESTAMP, end_effective_ts TIMESTAMP
)
USING DELTA
LOCATION 's3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/delta_tables/gold_delta_tables/store/';
-- s3://saleslake-101-251050869899-eu-north-1-an/saleslake-101/prod/delta_tables/gold_delta_tables/store/
